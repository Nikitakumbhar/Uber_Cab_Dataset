# %% [markdown]
# # Data Analyst Project @Great Learning
#
# Author: Nikita Kumbhar.
#
# Project Name : Uber Data Analysis with Python

# %% [markdown]
# # **Importing library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Read Data set 
data_cab=pd.read_csv("cab_rides.csv")

# %%
#See 1st 5 records 
data_cab.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
# To check information about data type
data_cab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %%
# To check shape of the data
data_cab.shape
# Out:
# (693071, 10)

# %%
# To check which columns present in dataset
data_cab.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name'],
#       dtype='object')

# %%
# To check null values
data_cab.isna().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
# To find discriptive statistics of numeric data
data_cab.describe()
# Out:
#             distance    time_stamp          price  surge_multiplier
# count  693071.000000  6.930710e+05  637976.000000     693071.000000
# mean        2.189430  1.544046e+12      16.545125          1.013870
# std         1.138937  6.891925e+08       9.324359          0.091641
# min         0.020000  1.543204e+12       2.500000          1.000000
# 25%         1.280000  1.543444e+12       9.000000          1.000000
# 50%         2.160000  1.543737e+12      13.500000          1.000000
# 75%         2.920000  1.544828e+12      22.500000          1.000000
# max         7.860000  1.545161e+12      97.500000          3.000000

# %% [markdown]
# # 2nd Dataset file reading

# %%
data_weather=pd.read_csv("weather.csv")

# %%
data_weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %%
data_weather.shape
# Out:
# (6276, 8)

# %%
data_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
data_weather.columns
# Out:
# Index(['temp', 'location', 'clouds', 'pressure', 'rain', 'time_stamp',
#        'humidity', 'wind'],
#       dtype='object')

# %%
data_weather.isna().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
data_weather.describe()
# Out:
#               temp       clouds     pressure        rain    time_stamp  \
# count  6276.000000  6276.000000  6276.000000  894.000000  6.276000e+03
# mean     39.090475     0.677777  1008.445209    0.057652  1.543857e+09
# std       6.022055     0.314284    12.870775    0.100758  6.659340e+05
# min      19.620000     0.000000   988.250000    0.000200  1.543204e+09
# 25%      36.077500     0.440000   997.747500    0.004900  1.543387e+09
# 50%      40.130000     0.780000  1007.660000    0.014850  1.543514e+09
# 75%      42.832500     0.970000  1018.480000    0.060925  1.544691e+09
# max      55.410000     1.000000  1035.120000    0.780700  1.545159e+09
#
#           humidity         wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# max       0.990000    18.180000

# %%
# To change datetime to time_stamp of cab dataset and weather dataset
import datetime
data_cab['datetime']=pd.to_datetime(data_cab['time_stamp'])
data_cab
data_weather['date_time']=pd.to_datetime(data_weather['time_stamp'])

# %%
df=pd.concat([data_cab,data_weather])   #combination of weather data and cab data

# %%
# see 1st 5 records of combining dataset
df.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name                      datetime  temp location  clouds  \
# ...

# %%
# create 'day' and 'hour' columns
df['day']=df.date_time.dt.day
df['hour']=df.date_time.dt.hour

# %%
df.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
# ...

# %%
# Fill null values with the help of zero(0)
df.fillna(0,inplace=True)

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime', 'temp',
#        'location', 'clouds', 'pressure', 'rain', 'humidity', 'wind',
#        'date_time', 'day', 'hour'],
#       dtype='object')

# %%
# To check any null value
df.isna().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# datetime            0
# temp                0
# location            0
# clouds              0
# pressure            0
# rain                0
# humidity            0
# wind                0
# date_time           0
# day                 0
# hour                0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis
# ### Exploratory data analysis is basically a technique to understand your
# ### data using statistics concept

# %%
## Heat Map for Data
plt.figure(figsize=[15,10])
sns.heatmap(df.corr(), annot=True, cmap="BuPu")
plt.show()

# %% [markdown]
# # *In correlation plot we see temprature, clouds, pressure, humidity, wind, day are highly positive correlated.*

# %%
# To find unique cab type 
df[ 'cab_type'].unique()
# Out:
# array(['Lyft', 'Uber', 0], dtype=object)

# %%
# plot cab type
plt.figure(figsize=(10,5))
sns.countplot(x='cab_type', hue='cab_type', data=df)
# Out:
# <AxesSubplot:xlabel='cab_type', ylabel='count'>

# %%
# To check unique source 
df[ 'source'].unique()
# Out:
# array(['Haymarket Square', 'Back Bay', 'North End', 'North Station',
#        'Beacon Hill', 'Boston University', 'Fenway', 'South Station',
#        'Theatre District', 'West End', 'Financial District',
#        'Northeastern University', 0], dtype=object)

# %%
# Plot unique source with cab type
plt.figure(figsize=(20,5))
sns.countplot(x='source', hue='cab_type', data=df)
# Out:
# <AxesSubplot:xlabel='source', ylabel='count'>

# %%
df['destination'].unique()
# Out:
# array(['North Station', 'Northeastern University', 'West End',
#        'Haymarket Square', 'South Station', 'Fenway', 'Theatre District',
#        'Beacon Hill', 'Back Bay', 'North End', 'Financial District',
#        'Boston University', 0], dtype=object)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='destination',hue='cab_type',data=df)
# Out:
# <AxesSubplot:xlabel='destination', ylabel='count'>

# %%
# To check different name of cab 
df['name'].unique()
# Out:
# array(['Shared', 'Lux', 'Lyft', 'Lux Black XL', 'Lyft XL', 'Lux Black',
#        'UberXL', 'Black', 'UberX', 'WAV', 'Black SUV', 'UberPool', 'Taxi',
#        0], dtype=object)

# %%
'''gen=['Unknown','Male','Female']
plt.pie(songs['gender'].value_counts(), labels = gen)
plt.show() 
'''
# Out:
# "gen=['Unknown','Male','Female']\nplt.pie(songs['gender'].value_counts(), labels = gen)\nplt.show() \n"

# %%
# Grouping with cab_type
df.groupby('cab_type').count()
# Out:
#           distance  time_stamp  destination  source   price  surge_multiplier  \
# cab_type
# 0             6276        6276         6276    6276    6276              6276
# Lyft        307408      307408       307408  307408  307408            307408
# Uber        385663      385663       385663  385663  385663            385663
#
#               id  product_id    name  datetime    temp  location  clouds  \
# cab_type
# 0           6276        6276    6276      6276    6276      6276    6276
# Lyft      307408      307408  307408    307408  307408    307408  307408
# Uber      385663      385663  385663    385663  385663    385663  385663
#
#           pressure    rain  humidity    wind  date_time     day    hour
# cab_type
# 0             6276    6276      6276    6276       6276    6276    6276
# Lyft        307408  307408    307408  307408     307408  307408  307408
# Uber        385663  385663    385663  385663     385663  385663  385663

# %%
df.groupby('cab_type').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='cab_type'>

# %%
# Ploting Price 
df['price'].value_counts().plot(kind='bar',figsize=(15,5),color='blue')
# Out:
# <AxesSubplot:>

# %%
# Plot the price with cab_type
plt.figure(figsize=(20,5))
sns.countplot(x='price',hue='cab_type',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='count'>

# %% [markdown]
# ### *We see Lyft price is more as compaire to Uber cab.*

# %%
# Plot hours with cab_type
plt.figure(figsize=(20,5))
sns.countplot(x='hour',hue='cab_type',data=df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %% [markdown]
# ### *Uber has more pick of hour as compaire to Lyft.*

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'datetime', 'temp',
#        'location', 'clouds', 'pressure', 'rain', 'humidity', 'wind',
#        'date_time', 'day', 'hour'],
#       dtype='object')

# %%
# Model making
x=df[['distance','surge_multiplier', 'temp','clouds', 'pressure', 'rain', 'humidity', 'wind',
       'day', 'hour']]
y=df['price']

# %%
#Using skicit learn to split data into training and testing 
from sklearn.model_selection import train_test_split
# Split the data into training and testing 
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_train,x_test)
# Out:
# LinearRegression()

# %%
prediction=linear.predict(y_train)

# %%
dff=pd.DataFrame({'Actual':y_test,'predicted':prediction})
dff
# Out:
#         Actual  predicted
# 81607     42.5  32.547916
# 354        0.0  14.755608
# 471801    32.5  16.816969
# 407645    27.5  10.480192
# 474760    27.5  10.556539
# ...        ...        ...
# 538489     7.5  10.709232
# 579511    13.5  15.519075
# 5421       9.0  11.828984
# 279982     8.0  11.854433
# 236315    27.5  13.228673
#
# [174837 rows x 2 columns]

# %%
#plot of Actual and predicted
dff1=dff.head(20)
dff1.plot(kind='bar',figsize=(26,10))
plt.grid(which='major',linestyle="-",linewidth='0.5',color='green')
plt.grid(which='minor',linestyle=":",linewidth='0.5',color='black')
plt.show()
